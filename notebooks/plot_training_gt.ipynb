# %%
# %matplotlib widget
from typing import Any, Dict, List, Tuple, Type, Optional, Union
from fmod.controller.workflow import WorkflowController

# %%
cname = "sres"
model =  'rcan-10-20-64'
ccustom: Dict[str,Any] = { 'pipeline.gpu': 1 }
yscale = "log"

configuration = dict(
	task = "swot",
	dataset = "swot",
	platform = "explore"
)

controller = WorkflowController( cname, configuration )
controller.init_plotting( cname, model, **ccustom )
# Out:
# load sres: config = {'task': 'swot', 'dataset': 'swot', 'platform': 'explore', 'model': 'rcan-10-20-64', 'pipeline.gpu': 1}
# ---------------------------------------------------------------------------
# MissingConfigException                    Traceback (most recent call last)
# Cell In[2], line 13
#       6 configuration = dict(
#       7 	task = "swot",
#       8 	dataset = "swot",
#       9 	platform = "explore"
#      10 )
#      12 controller = WorkflowController( cname, configuration )
# ---> 13 controller.init_plotting( cname, model, **ccustom )
#
# File /panfs/ccds02/nobackup/people/gtamkin/dev/super-resolution-fmod-overlay/notebooks/fmod/controller/workflow.py:40, in WorkflowController.init_plotting(self, cname, model, **kwargs)
#      38 def init_plotting(self, cname, model, **kwargs ):
#      39 	self.model = model
# ---> 40 	self.config = ConfigContext.activate_global( cname, model=model, **kwargs )
#      41 	self.trainer = ModelTrainer( self.config )
#
# File /panfs/ccds02/nobackup/people/gtamkin/dev/super-resolution-fmod-overlay/notebooks/fmod/base/util/config.py:72, in ConfigContext.activate_global(cls, name, **kwargs)
#      69 @classmethod
#      70 def activate_global(cls, name: str, **kwargs ) -> 'ConfigContext':
#      71     cc = ConfigContext( name, **kwargs )
# ---> 72     cc.activate()
#      73     return cc
#
# File /panfs/ccds02/nobackup/people/gtamkin/dev/super-resolution-fmod-overlay/notebooks/fmod/base/util/config.py:77, in ConfigContext.activate(self)
#      75 def activate(self):
#      76     assert ConfigContext.cfg is None, "Context already activated"
# ---> 77     cfg = ConfigContext.cfg = self.load()
#      78     gpu = self.configuration.get( 'gpu', int(os.getenv('FMOD_GPU',cfg.pipeline.gpu)) )
#      79     cfg.pipeline.gpu = gpu
#
# File /panfs/ccds02/nobackup/people/gtamkin/dev/super-resolution-fmod-overlay/notebooks/fmod/base/util/config.py:90, in ConfigContext.load(self)
#      88     hydra.initialize(version_base=None, config_path=self.config_path)
#      89 print( f"load {self.name}: config = {self.configuration}")
# ---> 90 return hydra.compose(config_name=self.name, overrides=[f"{ov[0]}={ov[1]}" for ov in self.configuration.items()])
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/compose.py:38, in compose(config_name, overrides, return_hydra_config, strict)
#      36 gh = GlobalHydra.instance()
#      37 assert gh.hydra is not None
# ---> 38 cfg = gh.hydra.compose_config(
#      39     config_name=config_name,
#      40     overrides=overrides,
#      41     run_mode=RunMode.RUN,
#      42     from_shell=False,
#      43     with_log_configuration=False,
#      44 )
#      45 assert isinstance(cfg, DictConfig)
#      47 if not return_hydra_config:
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/hydra.py:594, in Hydra.compose_config(self, config_name, overrides, run_mode, with_log_configuration, from_shell, validate_sweep_overrides)
#     576 def compose_config(
#     577     self,
#     578     config_name: Optional[str],
#    (...)
#     583     validate_sweep_overrides: bool = True,
#     584 ) -> DictConfig:
#     585     """
#     586     :param config_name:
#     587     :param overrides:
#    (...)
#     591     :return:
#     592     """
# --> 594     cfg = self.config_loader.load_configuration(
#     595         config_name=config_name,
#     596         overrides=overrides,
#     597         run_mode=run_mode,
#     598         from_shell=from_shell,
#     599         validate_sweep_overrides=validate_sweep_overrides,
#     600     )
#     601     if with_log_configuration:
#     602         configure_log(cfg.hydra.hydra_logging, cfg.hydra.verbose)
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/config_loader_impl.py:142, in ConfigLoaderImpl.load_configuration(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     133 def load_configuration(
#     134     self,
#     135     config_name: Optional[str],
#    (...)
#     139     validate_sweep_overrides: bool = True,
#     140 ) -> DictConfig:
#     141     try:
# --> 142         return self._load_configuration_impl(
#     143             config_name=config_name,
#     144             overrides=overrides,
#     145             run_mode=run_mode,
#     146             from_shell=from_shell,
#     147             validate_sweep_overrides=validate_sweep_overrides,
#     148         )
#     149     except OmegaConfBaseException as e:
#     150         raise ConfigCompositionException().with_traceback(sys.exc_info()[2]) from e
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/config_loader_impl.py:253, in ConfigLoaderImpl._load_configuration_impl(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     248 if validate_sweep_overrides:
#     249     self.validate_sweep_overrides_legal(
#     250         overrides=parsed_overrides, run_mode=run_mode, from_shell=from_shell
#     251     )
# --> 253 defaults_list = create_defaults_list(
#     254     repo=caching_repo,
#     255     config_name=config_name,
#     256     overrides_list=parsed_overrides,
#     257     prepend_hydra=True,
#     258     skip_missing=run_mode == RunMode.MULTIRUN,
#     259 )
#     261 config_overrides = defaults_list.config_overrides
#     263 cfg = self._compose_config_from_defaults_list(
#     264     defaults=defaults_list.defaults, repo=caching_repo
#     265 )
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:745, in create_defaults_list(repo, config_name, overrides_list, prepend_hydra, skip_missing)
#     736 """
#     737 :param repo:
#     738 :param config_name:
#    (...)
#     742 :return:
#     743 """
#     744 overrides = Overrides(repo=repo, overrides_list=overrides_list)
# --> 745 defaults, tree = _create_defaults_list(
#     746     repo,
#     747     config_name,
#     748     overrides,
#     749     prepend_hydra=prepend_hydra,
#     750     skip_missing=skip_missing,
#     751 )
#     752 overrides.ensure_overrides_used()
#     753 overrides.ensure_deletions_used()
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:715, in _create_defaults_list(repo, config_name, overrides, prepend_hydra, skip_missing)
#     706 def _create_defaults_list(
#     707     repo: IConfigRepository,
#     708     config_name: Optional[str],
#    (...)
#     711     skip_missing: bool,
#     712 ) -> Tuple[List[ResultDefault], DefaultsTreeNode]:
#     713     root = _create_root(config_name=config_name, with_hydra=prepend_hydra)
# --> 715     defaults_tree = _create_defaults_tree(
#     716         repo=repo,
#     717         root=root,
#     718         overrides=overrides,
#     719         is_root_config=True,
#     720         interpolated_subtree=False,
#     721         skip_missing=skip_missing,
#     722     )
#     724     output = _tree_to_list(tree=defaults_tree)
#     725     ensure_no_duplicates_in_list(output)
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:356, in _create_defaults_tree(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     348 def _create_defaults_tree(
#     349     repo: IConfigRepository,
#     350     root: DefaultsTreeNode,
#    (...)
#     354     overrides: Overrides,
#     355 ) -> DefaultsTreeNode:
# --> 356     ret = _create_defaults_tree_impl(
#     357         repo=repo,
#     358         root=root,
#     359         is_root_config=is_root_config,
#     360         skip_missing=skip_missing,
#     361         interpolated_subtree=interpolated_subtree,
#     362         overrides=overrides,
#     363     )
#     365     return ret
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:457, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     455 if parent.is_virtual():
#     456     if is_root_config:
# --> 457         return _expand_virtual_root(repo, root, overrides, skip_missing)
#     458     else:
#     459         return root
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:280, in _expand_virtual_root(repo, root, overrides, skip_missing)
#     277 new_root = DefaultsTreeNode(node=d, parent=root)
#     278 d.update_parent("", "")
# --> 280 subtree = _create_defaults_tree_impl(
#     281     repo=repo,
#     282     root=new_root,
#     283     is_root_config=d.primary,
#     284     skip_missing=skip_missing,
#     285     interpolated_subtree=False,
#     286     overrides=overrides,
#     287 )
#     288 if subtree.children is None:
#     289     children.append(d)
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:573, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     570                 continue
#     572             new_root = DefaultsTreeNode(node=d, parent=root)
# --> 573             add_child(children, new_root)
#     575 # processed deferred interpolations
#     576 known_choices = _create_interpolation_map(overrides, defaults_list, self_added)
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:520, in _create_defaults_tree_impl.<locals>.add_child(child_list, new_root_)
#     516 def add_child(
#     517     child_list: List[Union[InputDefault, DefaultsTreeNode]],
#     518     new_root_: DefaultsTreeNode,
#     519 ) -> None:
# --> 520     subtree_ = _create_defaults_tree_impl(
#     521         repo=repo,
#     522         root=new_root_,
#     523         is_root_config=False,
#     524         interpolated_subtree=interpolated_subtree,
#     525         skip_missing=skip_missing,
#     526         overrides=overrides,
#     527     )
#     528     if subtree_.children is None:
#     529         child_list.append(new_root_.node)
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:488, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     486         parent.deleted = True
#     487         return root
# --> 488     config_not_found_error(repo=repo, tree=root)
#     490 assert loaded is not None
#     491 defaults_list = copy.deepcopy(loaded.defaults_list)
#
# File /panfs/ccds02/nobackup/people/sstrong/micromamba/envs/pytorch-dev-rapids-v23_10-v19/lib/python3.11/site-packages/hydra/_internal/defaults_list.py:799, in config_not_found_error(repo, tree)
#     796 lines = "\n".join(descs)
#     797 msg += "\nConfig search path:" + f"\n{lines}"
# --> 799 raise MissingConfigException(
#     800     missing_cfg_file=element.get_config_path(),
#     801     message=msg,
#     802     options=options,
#     803 )
#
# MissingConfigException: In 'sres': Could not find 'task/swot'
#
# Available options in 'task':
# 	cape_basin
# 	cape_basin_1x1
# 	cape_basin_3x3
# 	swot-1.1v
# 	swot-2.2v
# 	swot-tnorm
# Config search path:
# 	provider=hydra, path=pkg://hydra.conf
# 	provider=main, path=file:///panfs/ccds02/nobackup/people/gtamkin/dev/super-resolution-sst/tm/FMod/config
# 	provider=schema, path=structured://

# %%
controller.get_training_view( fsize=8.00 )
